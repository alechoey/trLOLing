# %% [markdown]
# # True League of Legends in Game (TrLOLinG) analysis
#    ## **By Alec Hoey (cs194-hl) and Michael Jun (cs194-hq)**
#
# * ## Introduction
# We built a data product for the popular computer game, League of Legends, a multiplayer online game, where players control an individual champion and try to destroy the enemy base by killing enemy team members and completing objectives. Since champions and their unique abilities play an important role in the outcome of the game, we built a product to help answer the question of which set of champion selections are most likely to lead to victory. We will specifically apply this to ranked, draft-pick play, a mode of gameplay where each team begins by banning three champions so no member on either team may select them in the match. After the banning phase, each team alternates having the next team member select a champion to play. Therefore, given the list of banned champions and the current draft picks of both the friendly and enemy team, our product will suggest a champion to select next that will maximize the probability of winning, given data of previous matches.

# %% [markdown]
# ## Shape of the Data
# Let's first begin by importing our data.

# %%
# import data from data/complete/games/...
import pandas as pd

DATA_PATH = "/Users/alechoey/Documents/Berkeley/Spring 2014/CS194/project/data/final/"
DATA_PATH = "/home/saasbook/trLOLing/data/final/"
def parse_game_stats(filename):
    df = pd.read_csv(filename)
    return df

champions_df = parse_game_stats(DATA_PATH + "incomplete/20140508005848122-games.csv")
champions_with_game_info_df = parse_game_stats(DATA_PATH + "complete/20140508053431252-games.csv")

print champions_df.head(10)
print champions_with_game_info_df.head(10)
# Out:
#    team1summoner1championId  team1summoner2championId  \
# 0                        51                        56
# 1                        56                        67
# 2                        69                        79
# 3                        17                        24
# 4                        43                        53
# 5                         5                         6
# 6                         2                         6
# 7                        10                        31
# 8                        29                        43
# 9                        56                        63
#
#    team1summoner3championId  team1summoner4championId  \
# 0                       107                       115
# 1                       101                       161
# 2                        80                       104
# 3                        45                        89
# 4                        92                       104
# ...

# %% [markdown]
# We see a long list of columns. Initially, the topic of interest is team composition. Which collection of 5 champions work well against some other collection of 5 champions? We filter out the 10 champions in the game, and if team 1 won or not.

# %%
champion_columns = [
    'team1summoner1championId',
    'team1summoner2championId',
    'team1summoner3championId',
    'team1summoner4championId',
    'team1summoner5championId',
    'team2summoner1championId',
    'team2summoner2championId',
    'team2summoner3championId',
    'team2summoner4championId',
    'team2summoner5championId',
    'team1summoner1win'
]

champion_plus_info_columns = [
    'team1summoner1championId',
    'team1summoner2championId',
    'team1summoner3championId', 
    'team1summoner4championId',
    'team1summoner5championId',
    'team1summoner1goldSpent',
    'team1summoner1goldEarned',
    'team1summoner1totalDamageTaken',
    'team1summoner1totalDamageDealt',
    'team1summoner1totalTimeCrowdControlDealt',
    'team1summoner1wardPlaced',
    'team1summoner1minionsKilled',
    'team1summoner1championsKilled',
    'team1summoner2goldSpent',
    'team1summoner2goldEarned',
    'team1summoner2totalDamageTaken',
    'team1summoner2totalDamageDealt',
    'team1summoner2totalTimeCrowdControlDealt',
    'team1summoner2wardPlaced',
    'team1summoner2minionsKilled',
    'team1summoner2championsKilled',
    'team1summoner3goldSpent',
    'team1summoner3goldEarned',
    'team1summoner3totalDamageTaken',
    'team1summoner3totalDamageDealt',
    'team1summoner3totalTimeCrowdControlDealt',
    'team1summoner3wardPlaced',
    'team1summoner3minionsKilled',
    'team1summoner3championsKilled',
    'team1summoner4goldSpent',
    'team1summoner4goldEarned',
    'team1summoner4totalDamageTaken',
    'team1summoner4totalDamageDealt',
    'team1summoner4totalTimeCrowdControlDealt',
    'team1summoner4wardPlaced',
    'team1summoner4minionsKilled',
    'team1summoner4championsKilled',
    'team1summoner5goldSpent',
    'team1summoner5goldEarned',
    'team1summoner5totalDamageTaken',
    'team1summoner5totalDamageDealt',
    'team1summoner5totalTimeCrowdControlDealt',
    'team1summoner5wardPlaced',
    'team1summoner5minionsKilled',
    'team1summoner5championsKilled',
    'team2summoner1championId',
    'team2summoner2championId',
    'team2summoner3championId',
    'team2summoner4championId', 
    'team2summoner5championId',
    'team2summoner1goldSpent',
    'team2summoner1goldEarned',
    'team2summoner1totalDamageTaken',
    'team2summoner1totalDamageDealt',
    'team2summoner1totalTimeCrowdControlDealt',
    'team2summoner1wardPlaced',
    'team2summoner1minionsKilled',
    'team2summoner1championsKilled',
    'team2summoner2goldSpent',
    'team2summoner2goldEarned',
    'team2summoner2totalDamageTaken',
    'team2summoner2totalDamageDealt',
    'team2summoner2totalTimeCrowdControlDealt',
    'team2summoner2wardPlaced',
    'team2summoner2minionsKilled',
    'team2summoner2championsKilled',
    'team2summoner3goldSpent',
    'team2summoner3goldEarned',
    'team2summoner3totalDamageTaken',
    'team2summoner3totalDamageDealt',
    'team2summoner3totalTimeCrowdControlDealt',
    'team2summoner3wardPlaced',
    'team2summoner3minionsKilled',
    'team2summoner3championsKilled',
    'team2summoner4goldSpent',
    'team2summoner4goldEarned',
    'team2summoner4totalDamageTaken',
    'team2summoner4totalDamageDealt',
    'team2summoner4totalTimeCrowdControlDealt',
    'team2summoner4wardPlaced',
    'team2summoner4minionsKilled',
    'team2summoner4championsKilled',
    'team2summoner5goldSpent',
    'team2summoner5goldEarned',
    'team2summoner5totalDamageTaken',
    'team2summoner5totalDamageDealt',
    'team2summoner5totalTimeCrowdControlDealt',
    'team2summoner5wardPlaced',
    'team2summoner5minionsKilled',
    'team2summoner5championsKilled',
    'team1summoner1win'
]

game_champs = champions_df[champion_columns]
game_champs.rename(columns={'team1summoner1win':'team1win'}, inplace=True)
print game_champs.head(10)

game_champs_with_info = champions_with_game_info_df[champion_plus_info_columns]
game_champs_with_info.rename(columns={'team1summoner1win':'team1win'}, inplace=True)
print game_champs_with_info.head(10)
# Out:
#    team1summoner1championId  team1summoner2championId  \
# 0                        51                        56
# 1                        56                        67
# 2                        69                        79
# 3                        17                        24
# 4                        43                        53
# 5                         5                         6
# 6                         2                         6
# 7                        10                        31
# 8                        29                        43
# 9                        56                        63
#
#    team1summoner3championId  team1summoner4championId  \
# 0                       107                       115
# 1                       101                       161
# 2                        80                       104
# 3                        45                        89
# 4                        92                       104
# ...

# %% [markdown]
# ## Data Analysis
#
# * ### Graph Processing
#
# We thought that Graph processing would work best to look at the different team compositions. We define the vertex in our graph to be the set of 5 champions in a team. We define a directed edge between two vertices, V1 to V2, to mean that V1 beat V2. Finally, we define the vertex id to be the concatenation of the 5 champion ids in each team. We export this to be the edge file to work with Graphx and scala.

# %%
# create new column of vertex Ids - we sort by champion id for uniqueness of vertex id, then join with 0 to make more unique
game_champs['team1vertexId'] = game_champs.apply(lambda row: '0'.join(map(str, sorted([row['team1summoner1championId'],
                                                                                       row['team1summoner2championId'],
                                                                                       row['team1summoner3championId'],
                                                                                       row['team1summoner4championId'],
                                                                                       row['team1summoner5championId']]))),
                                                                      axis=1)
game_champs['team2vertexId'] = game_champs.apply(lambda row: '0'.join(map(str, sorted([row['team2summoner1championId'],
                                                                                       row['team2summoner2championId'],
                                                                                       row['team2summoner3championId'],
                                                                                       row['team2summoner4championId'],
                                                                                       row['team2summoner5championId']]))),
                                                                      axis=1)

game_champs_with_info['team1vertexId'] = game_champs_with_info.apply(lambda row: '0'.join(map(str, sorted([row['team1summoner1championId'],
                                                                                                           row['team1summoner2championId'],
                                                                                                           row['team1summoner3championId'],
                                                                                                           row['team1summoner4championId'],
                                                                                                           row['team1summoner5championId']]))),
                                                                                          axis=1)
game_champs_with_info['team2vertexId'] = game_champs_with_info.apply(lambda row: '0'.join(map(str, sorted([row['team2summoner1championId'],
                                                                                                           row['team2summoner2championId'],
                                                                                                           row['team2summoner3championId'],
                                                                                                           row['team2summoner4championId'],
                                                                                                           row['team2summoner5championId']]))),
                                                                                          axis=1)
# create new columns of mapping between vertex Ids and vertex information
game_champs['team1vertexInfo'] = game_champs.apply(lambda row: ', '.join(map(str, sorted([row['team1summoner1championId'],
                                                                                          row['team1summoner2championId'],
                                                                                          row['team1summoner3championId'],
                                                                                          row['team1summoner4championId'],
                                                                                          row['team1summoner5championId']]))),
                                                                         axis=1)
game_champs['team2vertexInfo'] = game_champs.apply(lambda row: ', '.join(map(str, sorted([row['team2summoner1championId'],
                                                                                          row['team2summoner2championId'],
                                                                                          row['team2summoner3championId'],
                                                                                          row['team2summoner4championId'],
                                                                                          row['team2summoner5championId']]))),
                                                                         axis=1)

game_champs_with_info['team1vertexInfo'] = game_champs_with_info.apply(lambda row: ', '.join(map(str, sorted([row['team1summoner1championId'],
                                                                                                              row['team1summoner2championId'],
                                                                                                              row['team1summoner3championId'],
                                                                                                              row['team1summoner4championId'],
                                                                                                              row['team1summoner5championId']]))),
                                                                                          axis=1)
game_champs_with_info['team2vertexInfo'] = game_champs_with_info.apply(lambda row: ', '.join(map(str, sorted([row['team2summoner1championId'],
                                                                                                              row['team2summoner2championId'],
                                                                                                              row['team2summoner3championId'],
                                                                                                              row['team2summoner4championId'],
                                                                                                              row['team2summoner5championId']]))),
                                                                                          axis=1)

game_champs_with_info['team1goldSpent'] = game_champs_with_info.apply(lambda row: row['team1summoner1goldSpent'] + row['team1summoner2goldSpent'] + row['team1summoner3goldSpent'] + row['team1summoner4goldSpent'] + row['team1summoner5goldSpent'],
                                                                      axis=1)
game_champs_with_info['team2goldSpent'] = game_champs_with_info.apply(lambda row: row['team2summoner1goldSpent'] + row['team2summoner2goldSpent'] + row['team2summoner3goldSpent'] + row['team2summoner4goldSpent'] + row['team2summoner5goldSpent'],
                                                                      axis=1)

game_champs_with_info['team1goldEarned'] = game_champs_with_info.apply(lambda row: row['team1summoner1goldEarned'] + row['team1summoner2goldEarned'] + row['team1summoner3goldEarned'] + row['team1summoner4goldEarned'] + row['team1summoner5goldEarned'],
                                                                       axis=1)
game_champs_with_info['team2goldEarned'] = game_champs_with_info.apply(lambda row: row['team2summoner1goldEarned'] + row['team2summoner2goldEarned'] + row['team2summoner3goldEarned'] + row['team2summoner4goldEarned'] + row['team2summoner5goldEarned'],
                                                                       axis=1)

game_champs_with_info['team1totalDamageDealt'] = game_champs_with_info.apply(lambda row: row['team1summoner1totalDamageDealt'] + row['team1summoner2totalDamageDealt'] + row['team1summoner3totalDamageDealt'] + row['team1summoner4totalDamageDealt'] + row['team1summoner5totalDamageDealt'],
                                                                             axis=1)
game_champs_with_info['team2totalDamageDealt'] = game_champs_with_info.apply(lambda row: row['team2summoner1totalDamageDealt'] + row['team2summoner2totalDamageDealt'] + row['team2summoner3totalDamageDealt'] + row['team2summoner4totalDamageDealt'] + row['team2summoner5totalDamageDealt'],
                                                                             axis=1)

game_champs_with_info['team1totalTimeCrowdControlDealt'] = game_champs_with_info.apply(lambda row: row['team1summoner1totalTimeCrowdControlDealt'] + row['team1summoner2totalTimeCrowdControlDealt'] + row['team1summoner3totalTimeCrowdControlDealt'] + row['team1summoner4totalTimeCrowdControlDealt'] + row['team1summoner5totalTimeCrowdControlDealt'],
                                                                                       axis=1)
game_champs_with_info['team2totalTimeCrowdControlDealt'] = game_champs_with_info.apply(lambda row: row['team2summoner1totalTimeCrowdControlDealt'] + row['team2summoner2totalTimeCrowdControlDealt'] + row['team2summoner3totalTimeCrowdControlDealt'] + row['team2summoner4totalTimeCrowdControlDealt'] + row['team2summoner5totalTimeCrowdControlDealt'],
                                                                                       axis=1)

game_champs_with_info['team1wardPlaced'] = game_champs_with_info.apply(lambda row: row['team1summoner1wardPlaced'] + row['team1summoner2wardPlaced'] + row['team1summoner3wardPlaced'] + row['team1summoner4wardPlaced'] + row['team1summoner5wardPlaced'],
                                                                       axis=1)
game_champs_with_info['team2wardPlaced'] = game_champs_with_info.apply(lambda row: row['team2summoner1wardPlaced'] + row['team2summoner2wardPlaced'] + row['team2summoner3wardPlaced'] + row['team2summoner4wardPlaced'] + row['team2summoner5wardPlaced'],
                                                                       axis=1)

game_champs_with_info['team1minionsKilled'] = game_champs_with_info.apply(lambda row: row['team1summoner1minionsKilled'] + row['team1summoner2minionsKilled'] + row['team1summoner3minionsKilled'] + row['team1summoner4minionsKilled'] + row['team1summoner5minionsKilled'],
                                                                          axis=1)
game_champs_with_info['team2minionsKilled'] = game_champs_with_info.apply(lambda row: row['team2summoner1minionsKilled'] + row['team2summoner2minionsKilled'] + row['team2summoner3minionsKilled'] + row['team2summoner4minionsKilled'] + row['team2summoner5minionsKilled'],
                                                                          axis=1)

game_champs_with_info['team1championsKilled'] = game_champs_with_info.apply(lambda row: row['team1summoner1championsKilled'] + row['team1summoner2championsKilled'] + row['team1summoner3championsKilled'] + row['team1summoner4championsKilled'] + row['team1summoner5championsKilled'],
                                                                            axis=1)
game_champs_with_info['team2championsKilled'] = game_champs_with_info.apply(lambda row: row['team2summoner1championsKilled'] + row['team2summoner2championsKilled'] + row['team2summoner3championsKilled'] + row['team2summoner4championsKilled'] + row['team2summoner5championsKilled'],
                                                                            axis=1)

game_champs_with_info['team1goldSpentNormalized'] = game_champs_with_info.apply(lambda row: row['team1goldSpent'] / float(row['team1goldSpent'] + row['team2goldSpent']),
                                                                                axis=1)
game_champs_with_info['team2goldSpentNormalized'] = game_champs_with_info.apply(lambda row: row['team2goldSpent'] / float(row['team1goldSpent'] + row['team2goldSpent']),
                                                                                axis=1)
game_champs_with_info['team1goldEarnedNormalized'] = game_champs_with_info.apply(lambda row: row['team1goldEarned'] / float(row['team1goldEarned'] + row['team2goldEarned']),
                                                                                 axis=1)
game_champs_with_info['team2goldEarnedNormalized'] = game_champs_with_info.apply(lambda row: row['team2goldEarned'] / float(row['team1goldEarned'] + row['team2goldEarned']),
                                                                                 axis=1)
game_champs_with_info['team1totalDamageDealtNormalized'] = game_champs_with_info.apply(lambda row: row['team1totalDamageDealt'] / float(row['team1totalDamageDealt'] + row['team2totalDamageDealt']),
                                                                                       axis=1)
game_champs_with_info['team2totalDamageDealtNormalized'] = game_champs_with_info.apply(lambda row: row['team2totalDamageDealt'] / float(row['team1totalDamageDealt'] + row['team2totalDamageDealt']),
                                                                                       axis=1)
game_champs_with_info['team1totalTimeCrowdControlDealtNormalized'] = game_champs_with_info.apply(lambda row: row['team1totalTimeCrowdControlDealt'] / float(row['team1totalTimeCrowdControlDealt'] + row['team2totalTimeCrowdControlDealt']),
                                                                                                 axis=1)
game_champs_with_info['team2totalTimeCrowdControlDealtNormalized'] = game_champs_with_info.apply(lambda row: row['team2totalTimeCrowdControlDealt'] / float(row['team1totalTimeCrowdControlDealt'] + row['team2totalTimeCrowdControlDealt']),
                                                                                                 axis=1)
game_champs_with_info['team1wardPlacedNormalized'] = game_champs_with_info.apply(lambda row: row['team1wardPlaced'] / float(row['team1wardPlaced'] + row['team2wardPlaced']),
                                                                                 axis=1)
game_champs_with_info['team2wardPlacedNormalized'] = game_champs_with_info.apply(lambda row: row['team2wardPlaced'] / float(row['team1wardPlaced'] + row['team2wardPlaced']),
                                                                                 axis=1)
game_champs_with_info['team1minionsKilledNormalized'] = game_champs_with_info.apply(lambda row: row['team1minionsKilled'] / float(row['team1minionsKilled'] + row['team2minionsKilled']),
                                                                                    axis=1)
game_champs_with_info['team2minionsKilledNormalized'] = game_champs_with_info.apply(lambda row: row['team2minionsKilled'] / float(row['team1minionsKilled'] + row['team2minionsKilled']),
                                                                                    axis=1)
game_champs_with_info['team1championsKilledNormalized'] = game_champs_with_info.apply(lambda row: row['team1championsKilled'] / float(row['team1championsKilled'] + row['team2championsKilled']),
                                                                                      axis=1)
game_champs_with_info['team2championsKilledNormalized'] = game_champs_with_info.apply(lambda row: row['team2championsKilled'] / float(row['team1championsKilled'] + row['team2championsKilled']),
                                                                                      axis=1)
print game_champs[['team1vertexId',
                   'team2vertexId',
                   'team1vertexInfo',
                   'team2vertexInfo',
                   'team1win']].head(20)

print game_champs_with_info[['team1vertexId',
                             'team2vertexId',
                             'team1vertexInfo',
                             'team2vertexInfo',
                             'team1goldSpentNormalized',
                             'team2goldSpentNormalized',
                             'team1goldEarnedNormalized',
                             'team2goldEarnedNormalized',
                             'team1totalTimeCrowdControlDealtNormalized',
                             'team2totalTimeCrowdControlDealtNormalized',
                             'team1wardPlacedNormalized',
                             'team2wardPlacedNormalized',
                             'team1minionsKilledNormalized',
                             'team2minionsKilledNormalized',
                             'team1championsKilledNormalized',
                             'team2championsKilledNormalized',
                             'team1win']].head(20)
# Out:
#         team1vertexId      team2vertexId        team1vertexInfo  \
# 0   51056010701150267   1602905602380267  51, 56, 107, 115, 267
# 1   56067010101610238    160380560980236  56, 67, 101, 161, 238
# 2    6907908001040254     40370750770236   69, 79, 80, 104, 254
# 3     170240450890236    110590630890104    17, 24, 45, 89, 236
# 4    4305309201040121  19055012602360412   43, 53, 92, 104, 121
# 5       5060630670412    701908501190412      5, 6, 63, 67, 412
# 6       2060260990133  31069012601430412      2, 6, 26, 99, 133
# 7     100310360960119    160250260540143    10, 31, 36, 96, 119
# 8    2904306401210157    100190250420133   29, 43, 64, 121, 157
# 9    5606307601100412  11051011501170126   56, 63, 76, 110, 412
# 10    160510560580412    240250280760236    16, 51, 56, 58, 412
# 11    501708902360238     22044058061077    5, 17, 89, 236, 238
# 12     22055064078089    510560860890112     22, 55, 64, 78, 89
# 13   2903104001070134   2059012201260161   29, 31, 40, 107, 134
# ...

# %%
import math
variables = {'team1goldSpentNormalized': 1.0,
             'team2goldSpentNormalized': -1.0,
             'team1goldEarnedNormalized': 1.0,
             'team2goldEarnedNormalized': -1.0,
             'team1totalTimeCrowdControlDealtNormalized': 1.0,
             'team2totalTimeCrowdControlDealtNormalized': -1.0,
             'team1wardPlacedNormalized': 1.0,
             'team2wardPlacedNormalized': -1.0,
             'team1minionsKilledNormalized': 1.0,
             'team2minionsKilledNormalized': -1.0,
             'team1championsKilledNormalized': 1.0,
             'team2championsKilledNormalized': -1.0}
# Finally, export to edge file
def calculate_weight(row):
    score = int(sum(map(lambda key: variables[key] * (0 if math.isnan(row[key]) else row[key]), variables)) * 10000)
    return score if row['team1win'] else -score

game_champs['Source'] = game_champs.apply(lambda row: int(row['team1vertexId']) if row['team1win'] else int(row['team2vertexId']), axis=1) 
game_champs['Target'] = game_champs.apply(lambda row: int(row['team2vertexId']) if row['team1win'] else int(row['team1vertexId']), axis=1)
print game_champs[['Source', 'Target']].head(10)

game_champs_with_info['Weight'] = game_champs_with_info.apply(calculate_weight, axis=1)
game_champs_with_info['Source'] = game_champs_with_info.apply(lambda row: int(row['team1vertexId']) if row['team1win'] else int(row['team2vertexId']), axis=1) 
game_champs_with_info['Target'] = game_champs_with_info.apply(lambda row: int(row['team2vertexId']) if row['team1win'] else int(row['team1vertexId']), axis=1)
print game_champs_with_info[['Source', 'Target', 'Weight']].head(10)
# Out:
#               Source             Target
# 0   1602905602380267  51056010701150267
# 1    160380560980236  56067010101610238
# 2     40370750770236   6907908001040254
# 3    170240450890236    110590630890104
# 4   4305309201040121  19055012602360412
# 5    701908501190412      5060630670412
# 6  31069012601430412      2060260990133
# 7    100310360960119    160250260540143
# 8    100190250420133   2904306401210157
# 9   5606307601100412  11051011501170126
#
# [10 rows x 2 columns]
#                Source              Target  Weight
# 0       5037050051091      55058064067089    8555
# 1  620102011901270238    1106707601020117    7196
# 2      40190390990222      50705801190267    1332
# 3      43056076077081  270104012202380412    5817
# 4  900110011301570412      13040067077081   -1535
# 5    1603303901170222     210530770830115    9734
# 6   19067012201270267    2402505501040113    7845
# 7     100220560760412    5051012601570267    4779
# ...

# %%
# export it to edges
game_champs[['Source', 'Target']].to_csv(DATA_PATH + "viz/incomplete/visualizeChampionEdges.csv", sep=',', header=True, index=False)
game_champs[['Source', 'Target']].to_csv(DATA_PATH + "graphX/incomplete/graphXChampionEdges.txt", sep=' ', header=False, index=False)

# export the vertices by getting the id column and using summoner's champion id columns to get the description of each vertex
vertex_ids = [game_champs['team1vertexId'],  game_champs['team2vertexId']]
vertex_infos = [game_champs['team1vertexInfo'],  game_champs['team2vertexInfo']]
ids = pd.concat(vertex_ids, axis=0)
infos = pd.concat(vertex_infos, axis=0)
vertex_id_to_info = pd.concat([ids, infos], axis=1).drop_duplicates()
vertex_id_to_info.to_csv(DATA_PATH + "graphX/incomplete/graphXChampionVertices.txt", sep = ' ', header=False, index=False)

game_champs_with_info[['Source', 'Target', 'Weight']].to_csv(DATA_PATH + "viz/complete/visualizeChampionEdges.csv", sep=',', header=True, index=False)
game_champs_with_info[['Source', 'Target', 'Weight']].to_csv(DATA_PATH + "graphX/complete/graphXChampionEdges.txt", sep=' ', header=False, index=False)
vertex_ids = [game_champs_with_info['team1vertexId'],  game_champs_with_info['team2vertexId']]
vertex_infos = [game_champs_with_info['team1vertexInfo'],  game_champs_with_info['team2vertexInfo']]
ids = pd.concat(vertex_ids, axis=0)
infos = pd.concat(vertex_infos, axis=0)
vertex_id_to_info = pd.concat([ids, infos], axis=1).drop_duplicates()
vertex_id_to_info.to_csv(DATA_PATH + "graphX/complete/graphXChampionVertices.txt", sep = ' ', header=False, index=False)

# %%
vertex_id_to_info.head(10)
# Out:
#                     0                       1
# 0       5037050051091       5, 37, 50, 51, 91
# 1    1106707601020117    11, 67, 76, 102, 117
# 2      50705801190267      5, 7, 58, 119, 267
# 3      43056076077081      43, 56, 76, 77, 81
# 4  900110011301570412  90, 110, 113, 157, 412
# 5     210530770830115     21, 53, 77, 83, 115
# 6   19067012201270267   19, 67, 122, 127, 267
# 7    5051012601570267    5, 51, 126, 157, 267
# 8      13037064081099      13, 37, 64, 81, 99
# 9     160580760770222     16, 58, 76, 77, 222
#
# [10 rows x 2 columns]

# %% [markdown]
# * ### Looking at different champions and statistics
#
# We now want to view different champion statistics. We look back at game_champs to analyze the win rates of different champions.
