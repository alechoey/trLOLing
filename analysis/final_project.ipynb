# %% [markdown]
# # True League of Legends in Game (TrLOLinG) analysis
#    ## **By Alec Hoey (cs194-hl) and Michael Jun (cs194-hq)**
#
# * ## Introduction
# We built a data product for the popular computer game, League of Legends, a multiplayer online game, where players control an individual champion and try to destroy the enemy base by killing enemy team members and completing objectives. Since champions and their unique abilities play an important role in the outcome of the game, we built a product to help answer the question of which set of champion selections are most likely to lead to victory. We will specifically apply this to ranked, draft-pick play, a mode of gameplay where each team begins by banning three champions so no member on either team may select them in the match. After the banning phase, each team alternates having the next team member select a champion to play. Therefore, given the list of banned champions and the current draft picks of both the friendly and enemy team, our product will suggest a champion to select next that will maximize the probability of winning, given data of previous matches.

# %% [markdown]
# ## Shape of the Data
# Let's first begin by importing our data.

# %%
# import data from data/complete/games/...
import pandas as pd

DATA_PATH = "/Users/alechoey/Documents/Berkeley/Spring 2014/CS194/project"

def parse_game_stats(filename):
    df = pd.read_csv(filename)
    return df

games_df = parse_game_stats(DATA_PATH + "/data/final/20140507155446807-games.csv")
games_df.head(10)
# Out:
#    team1summoner1championId  team1summoner1spell1  team1summoner1spell2  \
# 0                        53                     4                     3
# 1                         7                     4                    14
# 2                        11                    11                    12
# 3                        13                     4                    21
# 4                         7                    14                     4
# 5                        10                     4                    14
# 6                        29                    21                     4
# 7                        19                     4                    11
# 8                         9                    11                     4
# 9                        32                    11                     4
#
#    team1summoner1level  team1summoner1goldEarned  team1summoner1numDeaths  \
# 0                   16                      9813                        1
# 1                   18                     14244                        7
# 2                   16                      9790                        8
# 3                   18                     12851                       12
# 4                   18                     15716                       10
# 5                   15                     11351                        2
# 6                    9                      4221                       10
# 7                   16                     11441                        7
# 8                   16                     12808                        8
# 9                   18                     13575                       13
#
#    team1summoner1turretsKilled  team1summoner1minionsKilled  \
# 0                            2                           46
# 1                            1                          181
# 2                            1                           49
# 3                          NaN                           39
# 4                          NaN                          153
# 5                            3                          161
# 6                          NaN                           47
# 7                          NaN                           42
# 8                            2                           69
# 9                          NaN                           34
#
#    team1summoner1championsKilled  team1summoner1goldSpent  \
# 0                              3                     8830
# 1                             11                    13720
# 2                              2                     8915
# 3                             11                    12275
# 4                             15                    14310
# 5                             11                     9035
# 6                              1                     3655
# 7                             12                    10370
# 8                             12                    12405
# 9                              4                    11755
#
#    team1summoner1totalDamageDealt  team1summoner1totalDamageTaken  \
# 0                           45610                           15601
# 1                          131789                           26134
# 2                          143239                           26355
# 3                           62709                           31767
# 4                          109178                           25450
# 5                           98287                           15542
# 6                           25258                           11984
# 7                          116854                           32361
# 8                          118412                           31680
# 9                          139905                           53449
#
#    team1summoner1doubleKills  team1summoner1killingSprees  \
# 0                        NaN                            1
# 1                        NaN                            2
# 2                        NaN                          NaN
# 3                          2                            4
# 4                          2                            3
# 5                        NaN                            3
# 6                        NaN                          NaN
# 7                          1                            4
# 8                          1                            3
# 9                        NaN                            1
#
#    team1summoner1largestKillingSpree  team1summoner1team team1summoner1win  \
# 0                                  2                 100              True
# 1                                  5                 100             False
# 2                                NaN                 100             False
# 3                                  2                 100              True
# 4                                  5                 100              True
# 5                                  6                 100              True
# 6                                NaN                 100             False
# 7                                  4                 100             False
# 8                                  4                 100             False
# 9                                  2                 100             False
#
#    team1summoner1neutralMinionsKilled  team1summoner1largestMultiKill  \
# 0                                   1                               1
# 1                                  11                               1
# 2                                  81                               1
# 3                                 NaN                               2
# 4                                   4                               3
# 5                                   3                               1
# 6                                 NaN                               1
# 7                                  71                               3
# 8                                  38                               4
# 9                                  51                               1
#
#    team1summoner1physicalDamageDealtPlayer
# 0                                    13680 ...
# 1                                    22555 ...
# 2                                   106708 ...
# 3                                    14980 ...
# 4                                    21985 ...
# 5                                    27556 ...
# 6                                    22918 ...
# 7                                    59401 ...
# 8                                    10417 ...
# 9                                    26221 ...
#
# [10 rows x 430 columns]

# %% [markdown]
# We see a long list of columns. Initially, the topic of interest is team composition. Which collection of 5 champions work well against some other collection of 5 champions? We filter out the 10 champions in the game, and if team 1 won or not.

# %%
columns = [
    'team1summoner1championId',
    'team1summoner2championId',
    'team1summoner3championId', 
    'team1summoner4championId',
    'team1summoner5championId',
    'team1summoner1goldSpent',
    'team1summoner1goldEarned',
    'team1summoner1totalDamageTaken',
    'team1summoner1totalDamageDealt',
    'team1summoner1totalTimeCrowdControlDealt',
    'team1summoner1wardPlaced',
    'team1summoner1minionsKilled',
    'team1summoner1championsKilled',
    'team1summoner2goldSpent',
    'team1summoner2goldEarned',
    'team1summoner2totalDamageTaken',
    'team1summoner2totalDamageDealt',
    'team1summoner2totalTimeCrowdControlDealt',
    'team1summoner2wardPlaced',
    'team1summoner2minionsKilled',
    'team1summoner2championsKilled',
    'team1summoner3goldSpent',
    'team1summoner3goldEarned',
    'team1summoner3totalDamageTaken',
    'team1summoner3totalDamageDealt',
    'team1summoner3totalTimeCrowdControlDealt',
    'team1summoner3wardPlaced',
    'team1summoner3minionsKilled',
    'team1summoner3championsKilled',
    'team1summoner4goldSpent',
    'team1summoner4goldEarned',
    'team1summoner4totalDamageTaken',
    'team1summoner4totalDamageDealt',
    'team1summoner4totalTimeCrowdControlDealt',
    'team1summoner4wardPlaced',
    'team1summoner4minionsKilled',
    'team1summoner4championsKilled',
    'team1summoner5goldSpent',
    'team1summoner5goldEarned',
    'team1summoner5totalDamageTaken',
    'team1summoner5totalDamageDealt',
    'team1summoner5totalTimeCrowdControlDealt',
    'team1summoner5wardPlaced',
    'team1summoner5minionsKilled',
    'team1summoner5championsKilled',
    'team2summoner1championId',
    'team2summoner2championId',
    'team2summoner3championId',
    'team2summoner4championId', 
    'team2summoner5championId',
    'team2summoner1goldSpent',
    'team2summoner1goldEarned',
    'team2summoner1totalDamageTaken',
    'team2summoner1totalDamageDealt',
    'team2summoner1totalTimeCrowdControlDealt',
    'team2summoner1wardPlaced',
    'team2summoner1minionsKilled',
    'team2summoner1championsKilled',
    'team2summoner2goldSpent',
    'team2summoner2goldEarned',
    'team2summoner2totalDamageTaken',
    'team2summoner2totalDamageDealt',
    'team2summoner2totalTimeCrowdControlDealt',
    'team2summoner2wardPlaced',
    'team2summoner2minionsKilled',
    'team2summoner2championsKilled',
    'team2summoner3goldSpent',
    'team2summoner3goldEarned',
    'team2summoner3totalDamageTaken',
    'team2summoner3totalDamageDealt',
    'team2summoner3totalTimeCrowdControlDealt',
    'team2summoner3wardPlaced',
    'team2summoner3minionsKilled',
    'team2summoner3championsKilled',
    'team2summoner4goldSpent',
    'team2summoner4goldEarned',
    'team2summoner4totalDamageTaken',
    'team2summoner4totalDamageDealt',
    'team2summoner4totalTimeCrowdControlDealt',
    'team2summoner4wardPlaced',
    'team2summoner4minionsKilled',
    'team2summoner4championsKilled',
    'team2summoner5goldSpent',
    'team2summoner5goldEarned',
    'team2summoner5totalDamageTaken',
    'team2summoner5totalDamageDealt',
    'team2summoner5totalTimeCrowdControlDealt',
    'team2summoner5wardPlaced',
    'team2summoner5minionsKilled',
    'team2summoner5championsKilled',
    'team1summoner1win'
]

game_champs = games_df[columns]
game_champs.rename(columns={'team1summoner1win':'team1win'}, inplace=True)
game_champs.head(10)
# Out:
#    team1summoner1championId  team1summoner2championId  \
# 0                        53                        74
# 1                         7                        44
# 2                        11                        58
# 3                        13                        17
# 4                         7                        13
# 5                        10                        68
# 6                        29                        58
# 7                        19                        22
# 8                         9                        24
# 9                        32                        62
#
#    team1summoner3championId  team1summoner4championId  \
# 0                        78                       106
# 1                        62                       127
# 2                        76                       222
# 3                        35                        76
# 4                       102                       222
# 5                        77                        89
# 6                        64                       117
# 7                        82                       111
# 8                       117                       222
# 9                       157                       222
#
#    team1summoner5championId  team1summoner1goldSpent  \
# 0                       157                     8830
# 1                       222                    13720
# 2                       412                     8915
# 3                        99                    12275
# 4                       412                    14310
# 5                       110                     9035
# 6                       161                     3655
# 7                       254                    10370
# 8                       238                    12405
# 9                       267                    11755
#
#    team1summoner1goldEarned  team1summoner1totalDamageTaken  \
# 0                      9813                           15601
# 1                     14244                           26134
# 2                      9790                           26355
# 3                     12851                           31767
# 4                     15716                           25450
# 5                     11351                           15542
# 6                      4221                           11984
# 7                     11441                           32361
# 8                     12808                           31680
# 9                     13575                           53449
#
#    team1summoner1totalDamageDealt  team1summoner1totalTimeCrowdControlDealt  \
# 0                           45610                                       114
# 1                          131789                                       127
# 2                          143239                                       284
# 3                           62709                                       170
# 4                          109178                                       142
# 5                           98287                                       111
# 6                           25258                                       102
# 7                          116854                                       691
# 8                          118412                                       451
# 9                          139905                                       349
#
#    team1summoner1wardPlaced  team1summoner1minionsKilled  \
# 0                         7                           46
# 1                         8                          181
# 2                         7                           49
# 3                       NaN                           39
# 4                         5                          153
# 5                        17                          161
# 6                         3                           47
# 7                         4                           42
# 8                        11                           69
# 9                         9                           34
#
#    team1summoner1championsKilled  team1summoner2goldSpent  \
# 0                              3                    10965
# 1                             11                    11570
# 2                              2                     8555
# 3                             11                    13030
# 4                             15                    14320
# 5                             11                     8775
# 6                              1                     4880
# 7                             12                     7950
# 8                             12                    12863
# 9                              4                    14305
#
#    team1summoner2goldEarned  team1summoner2totalDamageTaken  \
# 0                     13443                           13288
# 1                     11183                           39622
# 2                      9287                           31987
# 3                     14213                           23571
# 4                     16442                           30089
# 5                      9858                           12563
# 6                      5180                           14409
# 7                      9355                           18966
# 8                     13405                           33813
# 9                     14440                           40608
#
#    team1summoner2totalDamageDealt  team1summoner2totalTimeCrowdControlDealt  \
# 0                          144034                                        48
# 1                           70844                                       194
# 2                          117780                                       226
# 3                           82856                                       468
# 4                          153374                                       913
# 5                           87602                                       429
# 6                           43911                                        11
# 7                           84986                                       700
# 8                          101440                                       418
# 9                          138909                                        74
#
#    team1summoner2wardPlaced  team1summoner2minionsKilled
# 0                         1                          184 ...
# 1                        21                          106 ...
# 2                         4                          176 ...
# 3                        42                           68 ...
# 4                        11                          192 ...
# 5                         6                          153 ...
# 6                         3                           98 ...
# 7                         2                          155 ...
# 8                         3                          134 ...
# 9                         8                          188 ...
#
# [10 rows x 91 columns]

# %% [markdown]
# ## Data Analysis
#
# * ### Graph Processing
#
# We thought that Graph processing would work best to look at the different team compositions. We define the vertex in our graph to be the set of 5 champions in a team. We define a directed edge between two vertices, V1 to V2, to mean that V1 beat V2. Finally, we define the vertex id to be the concatenation of the 5 champion ids in each team. We export this to be the edge file to work with Graphx and scala.

# %%
# create new column of vertex Ids - we sort by champion id for uniqueness of vertex id, then join with 0 to make more unique
game_champs['team1vertexId'] = game_champs.apply(lambda row: '0'.join(map(str, sorted([row['team1summoner1championId'],
                                                                                       row['team1summoner2championId'],
                                                                                       row['team1summoner3championId'],
                                                                                       row['team1summoner4championId'],
                                                                                       row['team1summoner5championId']]))),
                                                 axis=1)
game_champs['team2vertexId'] = game_champs.apply(lambda row: '0'.join(map(str, sorted([row['team2summoner1championId'],
                                                                                       row['team2summoner2championId'],
                                                                                       row['team2summoner3championId'],
                                                                                       row['team2summoner4championId'],
                                                                                       row['team2summoner5championId']]))),
                                                 axis=1)
# create new columns of mapping between vertex Ids and vertex information
game_champs['team1vertexInfo'] = game_champs.apply(lambda row: ', '.join(map(str, sorted([row['team1summoner1championId'],
                                                                                          row['team1summoner2championId'],
                                                                                          row['team1summoner3championId'],
                                                                                          row['team1summoner4championId'],
                                                                                          row['team1summoner5championId']]))),
                                                    axis=1)
game_champs['team2vertexInfo'] = game_champs.apply(lambda row: ', '.join(map(str, sorted([row['team2summoner1championId'],
                                                                                          row['team2summoner2championId'],
                                                                                          row['team2summoner3championId'],
                                                                                          row['team2summoner4championId'],
                                                                                          row['team2summoner5championId']]))),
                                                   axis=1)

game_champs['team1goldSpent'] = game_champs.apply(
                                                  lambda row: row['team1summoner1goldSpent'] + row['team1summoner2goldSpent'] + row['team1summoner3goldSpent'] + row['team1summoner4goldSpent'] + row['team1summoner5goldSpent'],
                                                  axis=1)
game_champs['team2goldSpent'] = game_champs.apply(lambda row: row['team2summoner1goldSpent'] + row['team2summoner2goldSpent'] + row['team2summoner3goldSpent'] + row['team2summoner4goldSpent'] + row['team2summoner5goldSpent'],
                                                  axis=1)

game_champs['team1goldEarned'] = game_champs.apply(lambda row: row['team1summoner1goldEarned'] + row['team1summoner2goldEarned'] + row['team1summoner3goldEarned'] + row['team1summoner4goldEarned'] + row['team1summoner5goldEarned'],
                                                   axis=1)
game_champs['team2goldEarned'] = game_champs.apply(lambda row: row['team2summoner1goldEarned'] + row['team2summoner2goldEarned'] + row['team2summoner3goldEarned'] + row['team2summoner4goldEarned'] + row['team2summoner5goldEarned'],
                                                   axis=1)

game_champs['team1totalDamageDealt'] = game_champs.apply(lambda row: row['team1summoner1totalDamageDealt'] + row['team1summoner2totalDamageDealt'] + row['team1summoner3totalDamageDealt'] + row['team1summoner4totalDamageDealt'] + row['team1summoner5totalDamageDealt'],
                                                         axis=1)
game_champs['team2totalDamageDealt'] = game_champs.apply(lambda row: row['team2summoner1totalDamageDealt'] + row['team2summoner2totalDamageDealt'] + row['team2summoner3totalDamageDealt'] + row['team2summoner4totalDamageDealt'] + row['team2summoner5totalDamageDealt'],
                                                         axis=1)

game_champs['team1totalTimeCrowdControlDealt'] = game_champs.apply(lambda row: row['team1summoner1totalTimeCrowdControlDealt'] + row['team1summoner2totalTimeCrowdControlDealt'] + row['team1summoner3totalTimeCrowdControlDealt'] + row['team1summoner4totalTimeCrowdControlDealt'] + row['team1summoner5totalTimeCrowdControlDealt'],
                                                                   axis=1)
game_champs['team2totalTimeCrowdControlDealt'] = game_champs.apply(lambda row: row['team2summoner1totalTimeCrowdControlDealt'] + row['team2summoner2totalTimeCrowdControlDealt'] + row['team2summoner3totalTimeCrowdControlDealt'] + row['team2summoner4totalTimeCrowdControlDealt'] + row['team2summoner5totalTimeCrowdControlDealt'],
                                                                   axis=1)

game_champs['team1wardPlaced'] = game_champs.apply(lambda row: row['team1summoner1wardPlaced'] + row['team1summoner2wardPlaced'] + row['team1summoner3wardPlaced'] + row['team1summoner4wardPlaced'] + row['team1summoner5wardPlaced'],
                                                   axis=1)
game_champs['team2wardPlaced'] = game_champs.apply(lambda row: row['team2summoner1wardPlaced'] + row['team2summoner2wardPlaced'] + row['team2summoner3wardPlaced'] + row['team2summoner4wardPlaced'] + row['team2summoner5wardPlaced'],
                                                   axis=1)

game_champs['team1minionsKilled'] = game_champs.apply(lambda row: row['team1summoner1minionsKilled'] + row['team1summoner2minionsKilled'] + row['team1summoner3minionsKilled'] + row['team1summoner4minionsKilled'] + row['team1summoner5minionsKilled'],
                                                      axis=1)
game_champs['team2minionsKilled'] = game_champs.apply(lambda row: row['team2summoner1minionsKilled'] + row['team2summoner2minionsKilled'] + row['team2summoner3minionsKilled'] + row['team2summoner4minionsKilled'] + row['team2summoner5minionsKilled'],
                                                      axis=1)

game_champs['team1championsKilled'] = game_champs.apply(lambda row: row['team1summoner1championsKilled'] + row['team1summoner2championsKilled'] + row['team1summoner3championsKilled'] + row['team1summoner4championsKilled'] + row['team1summoner5championsKilled'],
                                                        axis=1)
game_champs['team2championsKilled'] = game_champs.apply(lambda row: row['team2summoner1championsKilled'] + row['team2summoner2championsKilled'] + row['team2summoner3championsKilled'] + row['team2summoner4championsKilled'] + row['team2summoner5championsKilled'],
                                                        axis=1)

game_champs['team1goldSpentNormalized'] = game_champs.apply(lambda row: row['team1goldSpent'] / float(row['team1goldSpent'] + row['team2goldSpent']),
                                                            axis=1)
game_champs['team2goldSpentNormalized'] = game_champs.apply(lambda row: row['team2goldSpent'] / float(row['team1goldSpent'] + row['team2goldSpent']),
                                                            axis=1)
game_champs['team1goldEarnedNormalized'] = game_champs.apply(lambda row: row['team1goldEarned'] / float(row['team1goldEarned'] + row['team2goldEarned']),
                                                             axis=1)
game_champs['team2goldEarnedNormalized'] = game_champs.apply(lambda row: row['team2goldEarned'] / float(row['team1goldEarned'] + row['team2goldEarned']),
                                                             axis=1)
game_champs['team1totalDamageDealtNormalized'] = game_champs.apply(lambda row: row['team1totalDamageDealt'] / float(row['team1totalDamageDealt'] + row['team2totalDamageDealt']),
                                                                   axis=1)
game_champs['team2totalDamageDealtNormalized'] = game_champs.apply(lambda row: row['team2totalDamageDealt'] / float(row['team1totalDamageDealt'] + row['team2totalDamageDealt']),
                                                                   axis=1)
game_champs['team1totalTimeCrowdControlDealtNormalized'] = game_champs.apply(lambda row: row['team1totalTimeCrowdControlDealt'] / float(row['team1totalTimeCrowdControlDealt'] + row['team2totalTimeCrowdControlDealt']),
                                                                             axis=1)
game_champs['team2totalTimeCrowdControlDealtNormalized'] = game_champs.apply(lambda row: row['team2totalTimeCrowdControlDealt'] / float(row['team1totalTimeCrowdControlDealt'] + row['team2totalTimeCrowdControlDealt']),
                                                                             axis=1)
game_champs['team1wardPlacedNormalized'] = game_champs.apply(lambda row: row['team1wardPlaced'] / float(row['team1wardPlaced'] + row['team2wardPlaced']),
                                                             axis=1)
game_champs['team2wardPlacedNormalized'] = game_champs.apply(lambda row: row['team2wardPlaced'] / float(row['team1wardPlaced'] + row['team2wardPlaced']),
                                                             axis=1)
game_champs['team1minionsKilledNormalized'] = game_champs.apply(lambda row: row['team1minionsKilled'] / float(row['team1minionsKilled'] + row['team2minionsKilled']),
                                                                axis=1)
game_champs['team2minionsKilledNormalized'] = game_champs.apply(lambda row: row['team2minionsKilled'] / float(row['team1minionsKilled'] + row['team2minionsKilled']),
                                                                axis=1)
game_champs['team1championsKilledNormalized'] = game_champs.apply(lambda row: row['team1championsKilled'] / float(row['team1championsKilled'] + row['team2championsKilled']),
                                                                  axis=1)
game_champs['team2championsKilledNormalized'] = game_champs.apply(lambda row: row['team2championsKilled'] / float(row['team1championsKilled'] + row['team2championsKilled']),
                                                                  axis=1)

game_champs[['team1vertexId',
             'team2vertexId',
             'team1vertexInfo',
             'team2vertexInfo',
             'team1goldSpentNormalized',
             'team2goldSpentNormalized',
             'team1goldEarnedNormalized',
             'team2goldEarnedNormalized',
             'team1totalTimeCrowdControlDealtNormalized',
             'team2totalTimeCrowdControlDealtNormalized',
             'team1wardPlacedNormalized',
             'team2wardPlacedNormalized',
             'team1minionsKilledNormalized',
             'team2minionsKilledNormalized',
             'team1championsKilledNormalized',
             'team2championsKilledNormalized',
             'team1win']].head(20)
# Out:
#         team1vertexId      team2vertexId        team1vertexInfo  \
# 0    5307407801060157   9056010101100122   53, 74, 78, 106, 157
# 1     704406201270222  24051012101340412    7, 44, 62, 127, 222
# 2    1105807602220412       709015048075   11, 58, 76, 222, 412
# 3      13017035076099   3908208901120267     13, 17, 35, 76, 99
# 4    7013010202220412    106206701050122   7, 13, 102, 222, 412
# 5     100680770890110     40670770810105    10, 68, 77, 89, 110
# 6    2905806401170161      4090110480133   29, 58, 64, 117, 161
# 7    1902208201110254     50120780810238   19, 22, 82, 111, 254
# 8    9024011702220238     50410510890119   9, 24, 117, 222, 238
# 9   32062015702220267    350370550580119  32, 62, 157, 222, 267
# 10     40530580620157    802507601070110     4, 53, 58, 62, 157
# 11     10021043064092    370480640810134     10, 21, 43, 64, 92
# 12  39067010301110117  29058011502540412  39, 67, 103, 111, 117
# 13      5070890920222      1070110920222      5, 7, 89, 92, 222
# 14  22076011101150157   1107808501210157  22, 76, 111, 115, 157
# 15  19075011701190131   1702302401170412  19, 75, 117, 119, 131
# 16       204012029064     50220530830115       2, 4, 12, 29, 64
# 17   4011011001170122  16076010701170266   4, 11, 110, 117, 122
# 18  24055011902540412     70620640890222  24, 55, 119, 254, 412
# 19    220610620890106   1001101902220238    22, 61, 62, 89, 106
#
#           team2vertexInfo  team1goldSpentNormalized  team2goldSpentNormalized  \
# 0    9, 56, 101, 110, 122                  0.565143                  0.434857
# 1   24, 51, 121, 134, 412                  0.480284                  0.519716
# 2        7, 9, 15, 48, 75                  0.446967                  0.553033
# 3    39, 82, 89, 112, 267                  0.524426                  0.475574
# 4     1, 62, 67, 105, 122                  0.536696                  0.463304
# 5      4, 67, 77, 81, 105                  0.528146                  0.471854
# 6       4, 9, 11, 48, 133                  0.383380                  0.616620
# 7      5, 12, 78, 81, 238                  0.416530                  0.583470
# 8      5, 41, 51, 89, 119                  0.465911                  0.534089
# 9     35, 37, 55, 58, 119                  0.456917                  0.543083
# 10    8, 25, 76, 107, 110                  0.581188                  0.418812
# 11    37, 48, 64, 81, 134                  0.403805                  0.596195
# 12  29, 58, 115, 254, 412                  0.448789                  0.551211
# 13      1, 7, 11, 92, 222                  0.530574                  0.469426
# 14   11, 78, 85, 121, 157                  0.497979                  0.502021
# 15   17, 23, 24, 117, 412                  0.546640                  0.453360
# 16     5, 22, 53, 83, 115                  0.482829                  0.517171
# 17  16, 76, 107, 117, 266                  0.394727                  0.605273
# 18     7, 62, 64, 89, 222                  0.518196                  0.481804
# 19   10, 11, 19, 222, 238                  0.499382                  0.500618
#
#     team1goldEarnedNormalized  team2goldEarnedNormalized  \
# 0                    0.570717                   0.429283
# 1                    0.456307                   0.543693
# 2                    0.450446                   0.549554
# 3                    0.507609                   0.492391
# 4                    0.549005                   0.450995
# 5                    0.552689                   0.447311
# 6                    0.365959                   0.634041
# 7                    0.436548                   0.563452
# 8                    0.433106                   0.566894
# 9                    0.486507                   0.513493
# 10                   0.577033                   0.422967
# 11                   0.399510                   0.600490
# 12                   0.442867                   0.557133
# 13                   0.566804                   0.433196
# 14                   0.510086                   0.489914
# 15                   0.563992                   0.436008
# 16                   0.499291                   0.500709
# 17                   0.373105                   0.626895
# 18                   0.526273                   0.473727
# 19                   0.535355                   0.464645
#
#     team1totalTimeCrowdControlDealtNormalized  \
# 0                                    0.223448
# 1                                    0.353671
# 2                                    0.338553
# 3                                    0.438199
# 4                                    0.581535
# 5                                    0.531463
# 6                                    0.494036
# 7                                         NaN
# 8                                    0.338135
# 9                                    0.429176
# 10                                        NaN
# 11                                        NaN
# 12                                   0.460028
# 13                                   0.793651
# 14                                   0.687144
# 15                                   0.699137
# 16                                   0.521273
# 17                                   0.218349
# 18                                   0.483634
# 19                                   0.769164
#
#     team2totalTimeCrowdControlDealtNormalized  team1wardPlacedNormalized  \
# 0                                    0.776552                   0.513889
# 1                                    0.646329                   0.405405
# 2                                    0.661447                   0.400000
# 3                                    0.561801                        NaN
# 4                                    0.418465                        NaN
# 5                                    0.468537                   0.571429
# 6                                    0.505964                        NaN
# 7                                         NaN                   0.311688
# 8                                    0.661865                   0.619469
# 9                                    0.570824                   0.504505
# 10                                        NaN                   0.698413
# 11                                        NaN                   0.460526
# 12                                   0.539972                   0.550000
# 13                                   0.206349                   0.564815
# 14                                   0.312856                        NaN
# 15                                   0.300863                   0.407407
# 16                                   0.478727                   0.528926
# 17                                   0.781651                        NaN
# 18                                   0.516366                   0.478788
# 19                                   0.230836                   0.388489
#
#     team2wardPlacedNormalized  team1minionsKilledNormalized  \
# 0                    0.486111                      0.519135
# 1                    0.594595                      0.513599
# 2                    0.600000                      0.505932
# 3                         NaN                      0.526923
# 4                         NaN                      0.444867
# 5                    0.428571                      0.507756
# 6                         NaN                      0.381410
# 7                    0.688312                      0.421857
# 8                    0.380531                      0.428110
# 9                    0.495495                      0.444984
# 10                   0.301587                      0.596702
# 11                   0.539474                      0.459087
# 12                   0.450000                      0.476676
# 13                   0.435185                      0.527387
# 14                        NaN                      0.471634
# 15                   0.592593                      0.520206
# 16                   0.471074                      0.532590
# 17                        NaN                      0.385382
# 18                   0.521212                      0.459276
# 19                   0.611511                      0.533708
#
#     team2minionsKilledNormalized  team1championsKilledNormalized  \
# 0                       0.480865                        0.637931
# 1                       0.486401                        0.459459
# 2                       0.494068                        0.478261
# 3                       0.473077                        0.563107
# 4                       0.555133                        0.557895
# 5                       0.492244                             NaN
# 6                       0.618590                             NaN
# 7                       0.578143                        0.428571
# 8                       0.571890                        0.438202
# 9                       0.555016                        0.500000
# 10                      0.403298                        0.642857
# 11                      0.540913                        0.263158
# 12                      0.523324                        0.347826
# 13                      0.472613                        0.597015
# 14                      0.528366                        0.500000
# 15                      0.479794                        0.647887
# 16                      0.467410                        0.500000
# 17                      0.614618                             NaN
# 18                      0.540724                        0.529851
# 19                      0.466292                             NaN
#
#     team2championsKilledNormalized team1win
# 0                         0.362069     True
# 1                         0.540541    False
# 2                         0.521739    False
# 3                         0.436893     True
# 4                         0.442105     True
# 5                              NaN     True
# 6                              NaN    False
# 7                         0.571429    False
# 8                         0.561798    False
# 9                         0.500000    False
# 10                        0.357143     True
# 11                        0.736842    False
# 12                        0.652174    False
# 13                        0.402985     True
# 14                        0.500000     True
# 15                        0.352113     True
# 16                        0.500000     True
# 17                             NaN    False
# 18                        0.470149     True
# 19                             NaN     True
#
# [20 rows x 17 columns]

# %%
import math
variables = {'team1goldSpentNormalized': 1.0,
             'team2goldSpentNormalized': -1.0,
             'team1goldEarnedNormalized': 1.0,
             'team2goldEarnedNormalized': -1.0,
             'team1totalTimeCrowdControlDealtNormalized': 1.0,
             'team2totalTimeCrowdControlDealtNormalized': -1.0,
             'team1wardPlacedNormalized': 1.0,
             'team2wardPlacedNormalized': -1.0,
             'team1minionsKilledNormalized': 1.0,
             'team2minionsKilledNormalized': -1.0,
             'team1championsKilledNormalized': 1.0,
             'team2championsKilledNormalized': -1.0}
# Finally, export to edge file
def calculate_weight(row):
    score = int(sum(map(lambda key: variables[key] * (0 if math.isnan(row[key]) else row[key]), variables)) * 10000)
    return score if row['team1win'] else -score
    
game_champs['Weight'] = game_champs.apply(calculate_weight, axis=1)
game_champs['Source'] = game_champs.apply(lambda row: int(row['team1vertexId']) if row['team1win'] else int(row['team2vertexId']), axis=1) 
game_champs['Target'] = game_champs.apply(lambda row: int(row['team2vertexId']) if row['team1win'] else int(row['team1vertexId']), axis=1)
game_champs[['Source', 'Target', 'Weight']].head(10)
# Out:
#               Source             Target  Weight
# 0   5307407801060157   9056010101100122     605
# 1  24051012101340412    704406201270222    6625
# 2       709015048075   1105807602220412    7596
# 3     13017035076099   3908208901120267    1205
# 4   7013010202220412    106206701050122    3399
# 5    100680770890110     40670770810105    3829
# 6      4090110480133   2905806401170161    7504
# 7     50120780810238   1902208201110254    9696
# 8     50410510890119   9024011702220238    5541
# 9    350370550580119  32062015702220267    3558
#
# [10 rows x 3 columns]

# %%
# export it to edges
game_champs[['Source', 'Target', 'Weight']].to_csv(DATA_PATH+"/visualizeChampionEdges.csv", sep=',', header=True, index=False)

game_champs[['Source', 'Target']].to_csv(DATA_PATH+"/graphXChampionEdges.txt", sep=' ', header=False, index=False)
# export the vertices by getting the id column and using summoner's champion id columns to get the description of each vertex
vertex_ids = [game_champs['team1vertexId'],  game_champs['team2vertexId']]
vertex_infos = [game_champs['team1vertexInfo'],  game_champs['team2vertexInfo']]
ids = pd.concat(vertex_ids, axis=0)
infos = pd.concat(vertex_infos, axis=0)
vertex_id_to_info = pd.concat([ids, infos], axis=1).drop_duplicates()
vertex_id_to_info.to_csv(DATA_PATH+"/graphXChampionVertices.txt", sep = ' ', header=False, index=False)

# %%
vertex_id_to_info.head(10)
# Out:
#                    0                      1
# 0   5307407801060157   53, 74, 78, 106, 157
# 1    704406201270222    7, 44, 62, 127, 222
# 2   1105807602220412   11, 58, 76, 222, 412
# 3     13017035076099     13, 17, 35, 76, 99
# 4   7013010202220412   7, 13, 102, 222, 412
# 5    100680770890110    10, 68, 77, 89, 110
# 6   2905806401170161   29, 58, 64, 117, 161
# 7   1902208201110254   19, 22, 82, 111, 254
# 8   9024011702220238   9, 24, 117, 222, 238
# 9  32062015702220267  32, 62, 157, 222, 267
#
# [10 rows x 2 columns]

# %% [markdown]
# * ### Looking at different champions and statistics
#
# We now want to view different champion statistics. We look back at game_champs to analyze the win rates of different champions.
